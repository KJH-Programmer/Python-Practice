# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("./lung_cancer_data.csv")
df
# Out:
#          Patient_ID  Age  Gender Smoking_History  Tumor_Size_mm  \
# 0       Patient0000   68    Male  Current Smoker      81.678677
# 1       Patient0001   58    Male    Never Smoked      78.448272
# 2       Patient0002   44    Male   Former Smoker      67.714305
# 3       Patient0003   72    Male  Current Smoker      70.806008
# 4       Patient0004   37  Female    Never Smoked      87.272433
# ...             ...  ...     ...             ...            ...
# 23653  Patient23653   45    Male   Former Smoker      91.279410
# 23654  Patient23654   31    Male  Current Smoker      45.139048
# 23655  Patient23655   74    Male   Former Smoker      89.640323
# 23656  Patient23656   47  Female   Former Smoker      45.770358
# 23657  Patient23657   64    Male   Former Smoker      13.460912
#
#       Tumor_Location      Stage          Treatment  Survival_Months  \
# 0         Lower Lobe  Stage III            Surgery               44
# ...

# %%
df = df[['Stage', 'Survival_Months']]
df
# Out:
#            Stage  Survival_Months
# 0      Stage III               44
# 1        Stage I              101
# 2        Stage I               69
# 3      Stage III               95
# 4       Stage IV              105
# ...          ...              ...
# 23653    Stage I               16
# 23654   Stage IV               81
# 23655   Stage IV               52
# 23656    Stage I               26
# 23657    Stage I                1
#
# [23658 rows x 2 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23658 entries, 0 to 23657
# Data columns (total 2 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Stage            23658 non-null  object
#  1   Survival_Months  23658 non-null  int64
# dtypes: int64(1), object(1)
# memory usage: 369.8+ KB

# %%
df.isnull().sum()
# Out:
# Stage              0
# Survival_Months    0
# dtype: int64

# %%
df["Stage"]=="Stage I"
# Out:
# 0        False
# 1         True
# 2         True
# 3        False
# 4        False
#          ...
# 23653     True
# 23654    False
# 23655    False
# 23656     True
# 23657     True
# Name: Stage, Length: 23658, dtype: bool

# %%
Stage_I = df[df["Stage"]=="Stage I"]
Stage_I
Stage_I.reset_index()
# Out:
#       index    Stage  Survival_Months
# 0         1  Stage I              101
# 1         2  Stage I               69
# 2         5  Stage I               49
# 3         6  Stage I               63
# 4         8  Stage I               35
# ...     ...      ...              ...
# 5900  23640  Stage I               74
# 5901  23647  Stage I               70
# 5902  23653  Stage I               16
# 5903  23656  Stage I               26
# 5904  23657  Stage I                1
#
# [5905 rows x 3 columns]

# %%
df["Stage"]=="Stage II"
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 23653    False
# 23654    False
# 23655    False
# 23656    False
# 23657    False
# Name: Stage, Length: 23658, dtype: bool

# %%
Stage_II = df[df["Stage"]=="Stage II"]
Stage_II
Stage_II.reset_index()
# Out:
#       index     Stage  Survival_Months
# 0        18  Stage II               59
# 1        19  Stage II                3
# 2        32  Stage II               27
# 3        41  Stage II               23
# 4        52  Stage II               84
# ...     ...       ...              ...
# 5815  23617  Stage II               65
# 5816  23629  Stage II               78
# 5817  23650  Stage II               24
# 5818  23651  Stage II               95
# 5819  23652  Stage II              100
#
# [5820 rows x 3 columns]

# %%
df["Smoking_History"]=="Former Smoker"
# Out:
# 0        False
# 1        False
# 2         True
# 3        False
# 4        False
#          ...
# 23653     True
# 23654    False
# 23655     True
# 23656     True
# 23657     True
# Name: Smoking_History, Length: 23658, dtype: bool

# %%
Former_df = df[df["Smoking_History"]=="Former Smoker"]
Former_df
Former_df.reset_index()
# Out:
#       index Smoking_History  Survival_Months
# 0         2   Former Smoker               69
# 1         8   Former Smoker               35
# 2        13   Former Smoker              100
# 3        17   Former Smoker              115
# 4        21   Former Smoker               40
# ...     ...             ...              ...
# 7993  23652   Former Smoker              100
# 7994  23653   Former Smoker               16
# 7995  23655   Former Smoker               52
# 7996  23656   Former Smoker               26
# 7997  23657   Former Smoker                1
#
# [7998 rows x 3 columns]

# %%
Stage_I["Survival_Months"].mean()
# Out:
# 59.58983911939035

# %%
Stage_II["Survival_Months"].mean()
# Out:
# 59.9106529209622

# %%
Former_df["Survival_Months"].mean()
# Out:
# 59.7491872968242
